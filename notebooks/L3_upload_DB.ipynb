# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from bs4 import BeautifulSoup
import h3
from shapely.geometry import Polygon

# %%
from dotenv import load_dotenv
import os

# Load the environment variables from .env file
load_dotenv()

from supabase import create_client, Client

url: str = os.environ.get("SUPABASE_URL")
key: str = os.environ.get("SUPABASE_KEY")
supabase: Client = create_client(url, key)

# %%
properties_df = pd.read_parquet('../data/L3/propeties.parquet')
nearby_df = pd.read_parquet('../data/L3/nearby_facilities.parquet')
hdb_df = pd.read_parquet('../data/L3/hdb_transaction.parquet')
private_df = pd.read_parquet('../data/L3/private_transaction.parquet')
listing_sales = pd.read_parquet('../data/L3/listing_sales.parquet')

# %%
nearby_df
# Out:
#            property_index          type  \
# 0   affinity at serangoon     preschool
# 0   affinity at serangoon  kindergarden
# 0   affinity at serangoon     preschool
# 0   affinity at serangoon     preschool
# 0   affinity at serangoon     preschool
# ..                    ...           ...
# 0            alkaff vista     preschool
# 0            alkaff vista   supermarket
# 0            alkaff vista     preschool
# 0            alkaff vista     preschool
# 0            alkaff vista        hawker
#
#                                                  name   distance_m
# 0           Little Footprints Preschool Group Pte Ltd  1281.873195
# 0   PCF Sparkletots Preschool @ Serangoon Blk 226 ...  1092.384876
# 0   PCF Sparkletots Preschool @ Serangoon Blk 226 ...  1092.384876
# 0   PCF Sparkletots Preschool @ Serangoon Blk 226 (KN  1092.384876
# 0                            ROSYTH CHILD CARE CENTRE  1047.524303
# ..                                                ...          ...
# ...

# %%
properties_df
# Out:
#                                     property_index blk_no  \
# 0   AFFINITY AT SERANGOON SERANGOON NORTH AVENUE 1     26
# 0         THE FLORENCE RESIDENCES HOUGANG AVENUE 2     83
# 0       THE GARDEN RESIDENCES SERANGOON NORTH VIEW      5
# 0              THE PROMENADE@PELIKAT JALAN PELIKAT    183
# 0                   PRIMO RESIDENCES JALAN PELIKAT    137
# ..                                             ...    ...
# 0                            457B SENGKANG WEST RD   457B
# 0                              106B BIDADARI PK DR   106B
# 0                            458B SENGKANG WEST RD   458B
# 0                              105A BIDADARI PK DR   105A
# 0                              106A BIDADARI PK DR   106A
#
#                    road_name                 building  \
# 0   SERANGOON NORTH AVENUE 1    AFFINITY AT SERANGOON
# 0           HOUGANG AVENUE 2  THE FLORENCE RESIDENCES
# 0       SERANGOON NORTH VIEW    THE GARDEN RESIDENCES
# ...

# %%
table = pq.read_table('data.parquet')
json_data = table.to_pandas().to_json(orient='records')

# Insert JSON data into Supabase
response = supabase.table('your_table_name').insert(json.loads(json_data)).execute()
print(response)
