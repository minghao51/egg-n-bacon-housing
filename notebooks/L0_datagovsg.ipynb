# %% [raw]
# ---
# This is a test comment to verify jupytext sync
#   kernelspec:
#     display_name: Python 3
#     language: python
#     name: python3
# ---

# %%
# import polars as pl
import json
import re
import sys

import pandas as pd
import requests

# Test comment for jupytext sync verification

# Add src directory to path for imports
sys.path.append('../src')

from data_helpers import save_parquet

# %% [markdown]
# # Custom scripts
# - scripts to retrive additional page with consideration for total records

# %%
def fetch_data(url: str, dataset_id: str) -> pd.DataFrame:
    """
    Fetches data from the Data.gov.sg API and returns a concatenated DataFrame.

    Args:
        url (str): The base URL for the API request.
        dataset_id (str): The ID of the dataset to fetch.

    Returns:
        pd.DataFrame: A concatenated DataFrame containing the fetched data.
    """
    _response_agg = []  # Initialize an empty list to store the DataFrames
    offset_value = 0  # Initialize the offset value
    total_records = 0  # Initialize the total records count

    while True:
        try:
            # Send a GET request to the API
            response = requests.get(url+dataset_id)
            response_text = json.loads(response.text)

            # Append the fetched data to the list
            _response_agg.append(pd.DataFrame.from_dict(response_text['result']['records']))

            # Check if there's a next page
            if 'next' not in response_text['result']['_links'].keys():
                break

            # Update the URL for the next page
            url = 'https://data.gov.sg' + response_text['result']['_links']['next']

            # Update the offset value and total records count
            match = re.search(r'offset=(\d+)', url)
            offset_value = int(match.group(1))
            total_records = response_text['result']['total']
            # print(total_records)

            # Break if the offset value exceeds the total records count
            if offset_value > total_records:
                break
        except Exception as e:
            print(f"Error: {e}")
            break

    # Concatenate the DataFrames
    df = pd.concat(_response_agg, ignore_index=True)

    return df

# %% [markdown]
# # Data Gov Sg data

# %% [markdown]
# ## Private Residential Property Transactions in Rest of Central Region, Quarterly
# ### New Launch/Resale/SubSale Counts
# - https://data.gov.sg/datasets/d_5785799d63a9da091f4e0b456291eeb8/view

# %%
property_transasctions = fetch_data(
    url="https://data.gov.sg/api/action/datastore_search?resource_id=",
    dataset_id="d_5785799d63a9da091f4e0b456291eeb8"
    )
save_parquet(property_transasctions, "raw_datagov_general_sale", source="data.gov.sg API")

# %% [markdown]
# ### Private Residential Property Rental Index , (Base Quarter 2009-Q1 = 100), Quarterly
# - https://data.gov.sg/datasets/d_8e4c50283fb7052a391dfb746a05c853/view

# %%
rental_index = fetch_data(
    url="https://data.gov.sg/api/action/datastore_search?resource_id=",
    dataset_id="d_8e4c50283fb7052a391dfb746a05c853"
    )
save_parquet(rental_index, "raw_datagov_rental_index", source="data.gov.sg API")

# %% [markdown]
# ### Private Residential Property Price Index (Base Quarter 2009-Q1 = 100), Quarterly
# - https://data.gov.sg/datasets/d_97f8a2e995022d311c6c68cfda6d034c/view

# %%
price_index = fetch_data(
    url="https://data.gov.sg/api/action/datastore_search?resource_id=",
    dataset_id="d_97f8a2e995022d311c6c68cfda6d034c"
    )
save_parquet(price_index, "raw_datagov_price_index", source="data.gov.sg API")

# %% [markdown]
# ### Median Annual Value and Property Tax By Type of Private Residential Property
# - Median Annual Value and Property Tax
# - https://data.gov.sg/datasets/d_774a81df45dca33112e59207e6dae1af/view

# %%
median_val_property_tax = fetch_data(
    url="https://data.gov.sg/api/action/datastore_search?resource_id=",
    dataset_id="d_774a81df45dca33112e59207e6dae1af"
    )
save_parquet(median_val_property_tax, "raw_datagov_median_price_via_property_type", source="data.gov.sg API")

# %% [markdown]
# ### Private Residential Property Transactions in the Whole of Singapore, Quarterly
# - Private Residential Property Transactions
# - https://data.gov.sg/datasets/d_7c69c943d5f0d89d6a9a773d2b51f337/view

# %%
private_residential_transactions_whole = fetch_data(
    url="https://data.gov.sg/api/action/datastore_search?resource_id=",
    dataset_id="d_7c69c943d5f0d89d6a9a773d2b51f337"
    )
save_parquet(private_residential_transactions_whole, "raw_datagov_private_transactions_property_type", source="data.gov.sg API")

# %% [markdown]
# ## Resale Flat Prices
# - https://data.gov.sg/collections/189/view
# - download manually, just converting it here

# %%
resale_flat_2015 = pd.read_csv('../data/raw_data/csv/ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv')
resale_flat_2017 = pd.read_csv('../data/raw_data/csv/ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv')

save_parquet(resale_flat_2015, "raw_datagov_resale_flat_2015_2016", source="data.gov.sg CSV")
save_parquet(resale_flat_2017, "raw_datagov_resale_flat_2017_onwards", source="data.gov.sg CSV")

# %%
# resale_flat_df = fetch_data(
#     url="https://data.gov.sg/api/action/datastore_search?resource_id=",
#     dataset_id="d_8b84c4ee58e3cfc0ece0d773c8ca6abc"
#     )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 resale_flat_df = fetch_data(
#       2     url="https://data.gov.sg/api/action/datastore_search?resource_id=",
#       3     dataset_id="d_8b84c4ee58e3cfc0ece0d773c8ca6abc"
#       4     )
#
# Cell In[2], line 19, in fetch_data(url, dataset_id)
#      16 while True:
#      17     try:
#      18         # Send a GET request to the API
# ---> 19         response = requests.get(url+dataset_id)
#      20         response_text = json.loads(response.text)
#      22         # Append the fetched data to the list
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/http/client.py:1390, in HTTPConnection.getresponse(self)
#    1388 try:
#    1389     try:
# -> 1390         response.begin()
#    1391     except ConnectionError:
#    1392         self.close()
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/envs/py311cv/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
save_parquet(resale_flat_df, "raw_datagov_resale_flat_price_2017onwards", source="data.gov.sg API")

# %%
response.json()
# Out:
# {'help': 'https://data.gov.sg/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'resource_id': 'd_ea9ed51da2787afaf8e51f827c304208',
#   'fields': [{'type': 'text', 'id': 'month'},
#    {'type': 'text', 'id': 'town'},
#    {'type': 'text', 'id': 'flat_type'},
#    {'type': 'text', 'id': 'block'},
#    {'type': 'text', 'id': 'street_name'},
#    {'type': 'text', 'id': 'storey_range'},
#    {'type': 'numeric', 'id': 'floor_area_sqm'},
#    {'type': 'text', 'id': 'flat_model'},
#    {'type': 'numeric', 'id': 'lease_commence_date'},
#    {'type': 'text', 'id': 'remaining_lease'},
#    {'type': 'numeric', 'id': 'resale_price'},
#    {'type': 'int4', 'id': '_id'}],
#   'records': [{'_id': 1,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '174',
#     'street_name': 'ANG MO KIO AVE 4',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '60',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1986',
#     'remaining_lease': '70',
#     'resale_price': '255000'},
#    {'_id': 2,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '541',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1981',
#     'remaining_lease': '65',
#     'resale_price': '275000'},
#    {'_id': 3,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '163',
#     'street_name': 'ANG MO KIO AVE 4',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '69',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '285000'},
#    {'_id': 4,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '446',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '290000'},
#    {'_id': 5,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '557',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '290000'},
#    {'_id': 6,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '603',
#     'street_name': 'ANG MO KIO AVE 5',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '290000'},
#    {'_id': 7,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '709',
#     'street_name': 'ANG MO KIO AVE 8',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '290000'},
#    {'_id': 8,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '333',
#     'street_name': 'ANG MO KIO AVE 1',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1981',
#     'remaining_lease': '65',
#     'resale_price': '293000'},
#    {'_id': 9,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '109',
#     'street_name': 'ANG MO KIO AVE 4',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1978',
#     'remaining_lease': '62',
#     'resale_price': '300000'},
#    {'_id': 10,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '564',
#     'street_name': 'ANG MO KIO AVE 3',
#     'storey_range': '13 TO 15',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1985',
#     'remaining_lease': '69',
#     'resale_price': '307500'},
#    {'_id': 11,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '218',
#     'street_name': 'ANG MO KIO AVE 1',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1976',
#     'remaining_lease': '60',
#     'resale_price': '308000'},
#    {'_id': 12,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '556',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '312000'},
#    {'_id': 13,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '156',
#     'street_name': 'ANG MO KIO AVE 4',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1981',
#     'remaining_lease': '65',
#     'resale_price': '312000'},
#    {'_id': 14,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '471',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '319000'},
#    {'_id': 15,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '434',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '320000'},
#    {'_id': 16,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '560',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '320000'},
#    {'_id': 17,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '332',
#     'street_name': 'ANG MO KIO AVE 1',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1981',
#     'remaining_lease': '65',
#     'resale_price': '325000'},
#    {'_id': 18,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '421',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '74',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '325000'},
#    {'_id': 19,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '506',
#     'street_name': 'ANG MO KIO AVE 8',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '325000'},
#    {'_id': 20,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '631',
#     'street_name': 'ANG MO KIO AVE 4',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1985',
#     'remaining_lease': '69',
#     'resale_price': '330000'},
#    {'_id': 21,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '153',
#     'street_name': 'ANG MO KIO AVE 5',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1981',
#     'remaining_lease': '65',
#     'resale_price': '330000'},
#    {'_id': 22,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '442',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '335000'},
#    {'_id': 23,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '558',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '338000'},
#    {'_id': 24,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '212',
#     'street_name': 'ANG MO KIO AVE 3',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1977',
#     'remaining_lease': '61',
#     'resale_price': '340000'},
#    {'_id': 25,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '152',
#     'street_name': 'ANG MO KIO AVE 5',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '82',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1981',
#     'remaining_lease': '65',
#     'resale_price': '340000'},
#    {'_id': 26,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '331',
#     'street_name': 'ANG MO KIO AVE 1',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1981',
#     'remaining_lease': '65',
#     'resale_price': '341000'},
#    {'_id': 27,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '121',
#     'street_name': 'ANG MO KIO AVE 3',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1978',
#     'remaining_lease': '62',
#     'resale_price': '345000'},
#    {'_id': 28,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '130',
#     'street_name': 'ANG MO KIO AVE 3',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '73',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '350000'},
#    {'_id': 29,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '564',
#     'street_name': 'ANG MO KIO AVE 3',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '82',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1985',
#     'remaining_lease': '69',
#     'resale_price': '355000'},
#    {'_id': 30,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '646',
#     'street_name': 'ANG MO KIO AVE 6',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '75',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '355000'},
#    {'_id': 31,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '424',
#     'street_name': 'ANG MO KIO AVE 3',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '73',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '370000'},
#    {'_id': 32,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '3 ROOM',
#     'block': '584',
#     'street_name': 'ANG MO KIO AVE 3',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '82',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '410000'},
#    {'_id': 33,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '412',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '92',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '385000'},
#    {'_id': 34,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '612',
#     'street_name': 'ANG MO KIO AVE 4',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '91',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '410000'},
#    {'_id': 35,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '562',
#     'street_name': 'ANG MO KIO AVE 3',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '92',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '416888'},
#    {'_id': 36,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '223',
#     'street_name': 'ANG MO KIO AVE 1',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '92',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1978',
#     'remaining_lease': '62',
#     'resale_price': '423000'},
#    {'_id': 37,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '150',
#     'street_name': 'ANG MO KIO AVE 5',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '93',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1981',
#     'remaining_lease': '65',
#     'resale_price': '438000'},
#    {'_id': 38,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '468',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '92',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '438000'},
#    {'_id': 39,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '177',
#     'street_name': 'ANG MO KIO AVE 4',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '91',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1981',
#     'remaining_lease': '65',
#     'resale_price': '450000'},
#    {'_id': 40,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '603',
#     'street_name': 'ANG MO KIO AVE 5',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '91',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '450000'},
#    {'_id': 41,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '415',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '92',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '465000'},
#    {'_id': 42,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '254',
#     'street_name': 'ANG MO KIO AVE 4',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '97',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1977',
#     'remaining_lease': '61',
#     'resale_price': '465000'},
#    {'_id': 43,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '207',
#     'street_name': 'ANG MO KIO AVE 1',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '97',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1976',
#     'remaining_lease': '60',
#     'resale_price': '475000'},
#    {'_id': 44,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '432',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '92',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '475000'},
#    {'_id': 45,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '117',
#     'street_name': 'ANG MO KIO AVE 4',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '98',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1978',
#     'remaining_lease': '62',
#     'resale_price': '476000'},
#    {'_id': 46,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '415',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '92',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '480000'},
#    {'_id': 47,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '428',
#     'street_name': 'ANG MO KIO AVE 3',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '92',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1978',
#     'remaining_lease': '62',
#     'resale_price': '483000'},
#    {'_id': 48,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '573',
#     'street_name': 'ANG MO KIO AVE 3',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '92',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '485000'},
#    {'_id': 49,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '418',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '99',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '486888'},
#    {'_id': 50,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '324',
#     'street_name': 'ANG MO KIO AVE 3',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '98',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1978',
#     'remaining_lease': '62',
#     'resale_price': '583000'},
#    {'_id': 51,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '4 ROOM',
#     'block': '596B',
#     'street_name': 'ANG MO KIO ST 52',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '93',
#     'flat_model': 'Model A',
#     'lease_commence_date': '2002',
#     'remaining_lease': '86',
#     'resale_price': '600888'},
#    {'_id': 52,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '5 ROOM',
#     'block': '234',
#     'street_name': 'ANG MO KIO AVE 3',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '125',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1993',
#     'remaining_lease': '77',
#     'resale_price': '533000'},
#    {'_id': 53,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '5 ROOM',
#     'block': '648',
#     'street_name': 'ANG MO KIO AVE 5',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '121',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '570000'},
#    {'_id': 54,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '5 ROOM',
#     'block': '253A',
#     'street_name': 'ANG MO KIO ST 21',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '138',
#     'flat_model': 'Model A',
#     'lease_commence_date': '1996',
#     'remaining_lease': '80',
#     'resale_price': '580000'},
#    {'_id': 55,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '5 ROOM',
#     'block': '439',
#     'street_name': 'ANG MO KIO AVE 10',
#     'storey_range': '19 TO 21',
#     'floor_area_sqm': '119',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '645000'},
#    {'_id': 56,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '5 ROOM',
#     'block': '306',
#     'street_name': 'ANG MO KIO AVE 1',
#     'storey_range': '13 TO 15',
#     'floor_area_sqm': '123',
#     'flat_model': 'Standard',
#     'lease_commence_date': '1977',
#     'remaining_lease': '61',
#     'resale_price': '650000'},
#    {'_id': 57,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '5 ROOM',
#     'block': '729',
#     'street_name': 'ANG MO KIO AVE 6',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '119',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '670000'},
#    {'_id': 58,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '5 ROOM',
#     'block': '315B',
#     'street_name': 'ANG MO KIO ST 31',
#     'storey_range': '13 TO 15',
#     'floor_area_sqm': '110',
#     'flat_model': 'Improved',
#     'lease_commence_date': '2006',
#     'remaining_lease': '90',
#     'resale_price': '755000'},
#    {'_id': 59,
#     'month': '2015-01',
#     'town': 'ANG MO KIO',
#     'flat_type': '5 ROOM',
#     'block': '700C',
#     'street_name': 'ANG MO KIO AVE 6',
#     'storey_range': '19 TO 21',
#     'floor_area_sqm': '111',
#     'flat_model': 'Improved',
#     'lease_commence_date': '2003',
#     'remaining_lease': '87',
#     'resale_price': '820000'},
#    {'_id': 60,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '2 ROOM',
#     'block': '620',
#     'street_name': 'BEDOK RESERVOIR RD',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '45',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1986',
#     'remaining_lease': '70',
#     'resale_price': '246000'},
#    {'_id': 61,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '2 ROOM',
#     'block': '38',
#     'street_name': 'BEDOK STH RD',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '44',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1978',
#     'remaining_lease': '62',
#     'resale_price': '255000'},
#    {'_id': 62,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '504',
#     'street_name': 'BEDOK NTH ST 3',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '59',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1978',
#     'remaining_lease': '62',
#     'resale_price': '270000'},
#    {'_id': 63,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '545',
#     'street_name': 'BEDOK NTH ST 3',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '280000'},
#    {'_id': 64,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '546',
#     'street_name': 'BEDOK NTH ST 3',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '280000'},
#    {'_id': 65,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '18',
#     'street_name': 'BEDOK STH RD',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '65',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1976',
#     'remaining_lease': '60',
#     'resale_price': '282000'},
#    {'_id': 66,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '550',
#     'street_name': 'BEDOK NTH AVE 1',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '285000'},
#    {'_id': 67,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '502',
#     'street_name': 'BEDOK NTH ST 3',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '59',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1978',
#     'remaining_lease': '62',
#     'resale_price': '285000'},
#    {'_id': 68,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '509',
#     'street_name': 'BEDOK NTH ST 3',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '285000'},
#    {'_id': 69,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '525',
#     'street_name': 'BEDOK NTH ST 3',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '285000'},
#    {'_id': 70,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '534',
#     'street_name': 'BEDOK NTH ST 3',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '60',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1986',
#     'remaining_lease': '70',
#     'resale_price': '285000'},
#    {'_id': 71,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '542',
#     'street_name': 'BEDOK NTH ST 3',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1985',
#     'remaining_lease': '69',
#     'resale_price': '285000'},
#    {'_id': 72,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '76',
#     'street_name': 'BEDOK NTH RD',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '59',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1978',
#     'remaining_lease': '62',
#     'resale_price': '288000'},
#    {'_id': 73,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '709',
#     'street_name': 'BEDOK RESERVOIR RD',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1981',
#     'remaining_lease': '65',
#     'resale_price': '288000'},
#    {'_id': 74,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '620',
#     'street_name': 'BEDOK RESERVOIR RD',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '68',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1986',
#     'remaining_lease': '70',
#     'resale_price': '290000'},
#    {'_id': 75,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '703',
#     'street_name': 'BEDOK RESERVOIR RD',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '291000'},
#    {'_id': 76,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '27',
#     'street_name': 'NEW UPP CHANGI RD',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '65',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1982',
#     'remaining_lease': '66',
#     'resale_price': '292000'},
#    {'_id': 77,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '42',
#     'street_name': 'CHAI CHEE ST',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1985',
#     'remaining_lease': '69',
#     'resale_price': '295000'},
#    {'_id': 78,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '426',
#     'street_name': 'BEDOK NTH RD',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '82',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '300000'},
#    {'_id': 79,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '530',
#     'street_name': 'BEDOK NTH ST 3',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '300000'},
#    {'_id': 80,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '420',
#     'street_name': 'BEDOK NTH ST 1',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '305000'},
#    {'_id': 81,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '105',
#     'street_name': 'BEDOK NTH AVE 4',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1977',
#     'remaining_lease': '61',
#     'resale_price': '308000'},
#    {'_id': 82,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '519',
#     'street_name': 'BEDOK NTH AVE 1',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '310000'},
#    {'_id': 83,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '548',
#     'street_name': 'BEDOK NTH AVE 1',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '310000'},
#    {'_id': 84,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '537',
#     'street_name': 'BEDOK NTH ST 3',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '310000'},
#    {'_id': 85,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '28',
#     'street_name': 'NEW UPP CHANGI RD',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '65',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1977',
#     'remaining_lease': '61',
#     'resale_price': '310000'},
#    {'_id': 86,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '100',
#     'street_name': 'BEDOK NTH AVE 4',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1978',
#     'remaining_lease': '62',
#     'resale_price': '310800'},
#    {'_id': 87,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '103',
#     'street_name': 'BEDOK RESERVOIR RD',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '70',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1985',
#     'remaining_lease': '69',
#     'resale_price': '313000'},
#    {'_id': 88,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '522',
#     'street_name': 'BEDOK NTH AVE 1',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '315000'},
#    {'_id': 89,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '551',
#     'street_name': 'BEDOK NTH AVE 1',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1980',
#     'remaining_lease': '64',
#     'resale_price': '315000'},
#    {'_id': 90,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '709',
#     'street_name': 'BEDOK RESERVOIR RD',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1981',
#     'remaining_lease': '65',
#     'resale_price': '315000'},
#    {'_id': 91,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '608',
#     'street_name': 'BEDOK RESERVOIR RD',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1982',
#     'remaining_lease': '66',
#     'resale_price': '318000'},
#    {'_id': 92,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '135',
#     'street_name': 'BEDOK NTH ST 2',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1978',
#     'remaining_lease': '62',
#     'resale_price': '320000'},
#    {'_id': 93,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '40',
#     'street_name': 'CHAI CHEE AVE',
#     'storey_range': '01 TO 03',
#     'floor_area_sqm': '65',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1974',
#     'remaining_lease': '58',
#     'resale_price': '320000'},
#    {'_id': 94,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '57',
#     'street_name': 'NEW UPP CHANGI RD',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '68',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1985',
#     'remaining_lease': '69',
#     'resale_price': '320000'},
#    {'_id': 95,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '420',
#     'street_name': 'BEDOK NTH ST 1',
#     'storey_range': '04 TO 06',
#     'floor_area_sqm': '68',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '323000'},
#    {'_id': 96,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '401',
#     'street_name': 'BEDOK NTH AVE 3',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '332000'},
#    {'_id': 97,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '2',
#     'street_name': 'BEDOK STH AVE 1',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '65',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1976',
#     'remaining_lease': '60',
#     'resale_price': '338000'},
#    {'_id': 98,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '2',
#     'street_name': 'BEDOK STH AVE 1',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '65',
#     'flat_model': 'Improved',
#     'lease_commence_date': '1976',
#     'remaining_lease': '60',
#     'resale_price': '339000'},
#    {'_id': 99,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '426',
#     'street_name': 'BEDOK NTH RD',
#     'storey_range': '10 TO 12',
#     'floor_area_sqm': '67',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1979',
#     'remaining_lease': '63',
#     'resale_price': '342000'},
#    {'_id': 100,
#     'month': '2015-01',
#     'town': 'BEDOK',
#     'flat_type': '3 ROOM',
#     'block': '116',
#     'street_name': 'BEDOK NTH RD',
#     'storey_range': '07 TO 09',
#     'floor_area_sqm': '73',
#     'flat_model': 'New Generation',
#     'lease_commence_date': '1978',
#     'remaining_lease': '62',
#     'resale_price': '355000'}],
#   '_links': {'start': '/api/action/datastore_search?resource_id=d_ea9ed51da2787afaf8e51f827c304208',
#    'next': '/api/action/datastore_search?resource_id=d_ea9ed51da2787afaf8e51f827c304208&offset=100'},
#   'total': 37153}}

# %%
resale_flat_df_jan2015 = fetch_data(
    url="https://data.gov.sg/api/action/datastore_search?resource_id=",
    dataset_id="d_ea9ed51da2787afaf8e51f827c304208"
    )

save_parquet(resale_flat_df_jan2015, "raw_datagov_resale_flat_price_2015_2016_api", source="data.gov.sg API")

# %% [markdown]
# ## Private Residential Property Transactions in Outside Central Region, Quarterly
# - https://data.gov.sg/datasets/d_1a7823f3d31e7db4b426833833762bab/view

# %%
private_residential_transactions_outside_central = fetch_data(
    url="https://data.gov.sg/api/action/datastore_search?resource_id=",
    dataset_id="d_1a7823f3d31e7db4b426833833762bab"
    )

# %% [markdown]
# ## Private Residential Property Transactions in Core Central Region, Quarterly
# - https://data.gov.sg/datasets/d_c287c8be114bfa7d055b27ab2c87de83/view

# %%
private_residential_transactions_central = fetch_data(
    url="https://data.gov.sg/api/action/datastore_search?resource_id=",
    dataset_id="d_c287c8be114bfa7d055b27ab2c87de83"
    )

# %% [markdown]
# ## Demand for Rental and Sold Flats
# - https://data.gov.sg/datasets/d_4b4ee36346b27fe35c529588900340b2/view

# %%
demand_rental_sold_flats = fetch_data(
    url="https://data.gov.sg/api/action/datastore_search?resource_id=",
    dataset_id="d_4b4ee36346b27fe35c529588900340b2"
    )

# %% [markdown]
# ## Number of Sold and Rented HDB Residential Units
# - https://data.gov.sg/datasets/d_67966e5fd5dce14cf9fa5f0bc5164faf/view

# %%
sold_rented_hdb = fetch_data(
    url="https://data.gov.sg/api/action/datastore_search?resource_id=",
    dataset_id="d_67966e5fd5dce14cf9fa5f0bc5164faf"
    )

# %% [markdown]
# ## Price Range of HDB Flats Offered
# - https://data.gov.sg/datasets/d_2d493bdcc1d9a44828b6e71cb095b88d/view

# %%
price_range_hdb = fetch_data(
    url="https://data.gov.sg/api/action/datastore_search?resource_id=",
    dataset_id="d_2d493bdcc1d9a44828b6e71cb095b88d"
    )

# %% [markdown]
# ## HDB Resale Price Index (1Q2009 = 100), Quarterly
# - https://data.gov.sg/datasets/d_14f63e595975691e7c24a27ae4c07c79/view

# %%
price_index_hdb = fetch_data(
    url="https://data.gov.sg/api/action/datastore_search?resource_id=",
    dataset_id="d_14f63e595975691e7c24a27ae4c07c79"
    )

# %% [markdown]
# ## Renting Out of Flats 2024 (CSV)
# - https://data.gov.sg/datasets/d_c9f57187485a850908655db0e8cfe651/view

# %%
renting_flats = fetch_data(
    url="https://data.gov.sg/api/action/datastore_search?resource_id=",
    dataset_id="d_c9f57187485a850908655db0e8cfe651"
    )
